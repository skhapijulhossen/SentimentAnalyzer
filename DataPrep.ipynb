# %% [markdown]
# # **Imports**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Load Data from Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/amazon'
data_path = '/content/drive/MyDrive/Colab Notebooks/amazon/AMAZON_FASHION.json'

# %%
data = pd.read_json(data_path, lines=True)

# %%
data
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0             5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1             2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2             4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3             2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4             3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...         ...       ...          ...             ...         ...
# 883631        5      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
# 883632        5      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
# 883633        3      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
# 883634        3      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
# 883635        5      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                reviewerName  \
# 0                     Tracy
# 1                 Sonja Lau
# 2                  Kathleen
# 3               Jodi Stoner
# 4              Alexander D.
# ...                     ...
# 883631      Amazon Customer
# 883632      Amazon Customer
# 883633             Fabfifty
# 883634               Mgomez
# 883635  Natasha Mascarenhas
#
#                                                reviewText  \
# 0                                  Exactly what I needed.
# 1       I agree with the other review, the opening is ...
# 2       Love these... I am going to order another pack...
# 3                                     too tiny an opening
# 4                                                    Okay
# ...                                                   ...
# 883631  I absolutely love this dress!!  It's sexy and ...
# 883632  I'm 5'6 175lbs. I'm on the tall side. I wear a...
# 883633                         Too big in the chest area!
# 883634                Too clear in the back, needs lining
# 883635  Ordered and was slightly small. Worked with th...
#
#                                                   summary  unixReviewTime  \
# 0                                  perfect replacements!!      1413763200
# 1       I agree with the other review, the opening is ...      1411862400
# 2                                     My New 'Friends' !!      1408924800
# 3                                               Two Stars      1408838400
# 4                                             Three Stars      1406419200
# ...                                                   ...             ...
# 883631                       I absolutely love this dress      1487635200
# 883632  I wear a large and ordered a large and it stil...      1480032000
# 883633                                        Three Stars      1478736000
# 883634                                        Three Stars      1478736000
# 883635         The quality is excellent and it is so cute      1470700800
#
#         vote style image
# 0        NaN   NaN   NaN
# 1        3.0   NaN   NaN
# 2        NaN   NaN   NaN
# 3        NaN   NaN   NaN
# 4        NaN   NaN   NaN
# ...      ...   ...   ...
# 883631   NaN   NaN   NaN
# 883632   2.0   NaN   NaN
# 883633   NaN   NaN   NaN
# 883634   NaN   NaN   NaN
# 883635   NaN   NaN   NaN
#
# [883636 rows x 12 columns]

# %%
data.shape
# Out:
# (883636, 12)

# %% [markdown]
# # Missing Values Inspection

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883636 entries, 0 to 883635
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         883636 non-null  int64
#  1   verified        883636 non-null  bool
#  2   reviewTime      883636 non-null  object
#  3   reviewerID      883636 non-null  object
#  4   asin            883636 non-null  object
#  5   reviewerName    883544 non-null  object
#  6   reviewText      882403 non-null  object
#  7   summary         883103 non-null  object
#  8   unixReviewTime  883636 non-null  int64
#  9   vote            79900 non-null   float64
#  10  style           304569 non-null  object
#  11  image           28807 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(8)
# memory usage: 75.0+ MB

# %%
data.isnull().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# reviewerName          92
# reviewText          1233
# summary              533
# unixReviewTime         0
# vote              803736
# style             579067
# image             854829
# dtype: int64

# %%
# @ dropping columns vote, style, image because it have large number of missing values
data.drop(columns=['vote', 'style', 'image'], inplace=True)

# %%
# @ dropping some rows  because it have minimal number of missing values in revieText and Summary column
data.dropna(axis=0, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881810 entries, 0 to 883635
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         881810 non-null  int64
#  1   verified        881810 non-null  bool
#  2   reviewTime      881810 non-null  object
#  3   reviewerID      881810 non-null  object
#  4   asin            881810 non-null  object
#  5   reviewerName    881810 non-null  object
#  6   reviewText      881810 non-null  object
#  7   summary         881810 non-null  object
#  8   unixReviewTime  881810 non-null  int64
# dtypes: bool(1), int64(2), object(6)
# memory usage: 61.4+ MB

# %% [markdown]
# # Duplicate Inspection

# %%
data.duplicated(subset=['reviewText']).sum()
# Out:
# 113528

# %%
data.drop_duplicates(subset=['reviewText'], keep='last', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768282 entries, 1 to 883635
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         768282 non-null  int64
#  1   verified        768282 non-null  bool
#  2   reviewTime      768282 non-null  object
#  3   reviewerID      768282 non-null  object
#  4   asin            768282 non-null  object
#  5   reviewerName    768282 non-null  object
#  6   reviewText      768282 non-null  object
#  7   summary         768282 non-null  object
#  8   unixReviewTime  768282 non-null  int64
# dtypes: bool(1), int64(2), object(6)
# memory usage: 53.5+ MB

# %%
data
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 1             2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2             4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3             2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 6             4      True  05 31, 2014   A7QS961ROI6E0  7106116521
# 7             3      True  09 22, 2013  A1BB77SEBQT8VX  B00007GDFV
# ...         ...       ...          ...             ...         ...
# 883631        5      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
# 883632        5      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
# 883633        3      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
# 883634        3      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
# 883635        5      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                reviewerName  \
# 1                 Sonja Lau
# 2                  Kathleen
# 3               Jodi Stoner
# 6          REBECCA S LAYTON
# 7        Darrow H Ankrum II
# ...                     ...
# 883631      Amazon Customer
# 883632      Amazon Customer
# 883633             Fabfifty
# 883634               Mgomez
# 883635  Natasha Mascarenhas
#
#                                                reviewText  \
# 1       I agree with the other review, the opening is ...
# 2       Love these... I am going to order another pack...
# 3                                     too tiny an opening
# 6       These little plastic backs work great.  No mor...
# 7       mother - in - law wanted it as a present for h...
# ...                                                   ...
# 883631  I absolutely love this dress!!  It's sexy and ...
# 883632  I'm 5'6 175lbs. I'm on the tall side. I wear a...
# 883633                         Too big in the chest area!
# 883634                Too clear in the back, needs lining
# 883635  Ordered and was slightly small. Worked with th...
#
#                                                   summary  unixReviewTime
# 1       I agree with the other review, the opening is ...      1411862400
# 2                                     My New 'Friends' !!      1408924800
# 3                                               Two Stars      1408838400
# 6                                            Works great!      1401494400
# 7                                     bought as a present      1379808000
# ...                                                   ...             ...
# 883631                       I absolutely love this dress      1487635200
# 883632  I wear a large and ordered a large and it stil...      1480032000
# 883633                                        Three Stars      1478736000
# 883634                                        Three Stars      1478736000
# 883635         The quality is excellent and it is so cute      1470700800
#
# [768282 rows x 9 columns]

# %%
# @ Average rewview sentiment
data.describe().T
# Out:
#                    count          mean           std           min  \
# overall         768282.0  3.845322e+00  1.438182e+00  1.000000e+00
# unixReviewTime  768282.0  1.456057e+09  4.495822e+07  1.036973e+09
#
#                          25%           50%           75%           max
# overall         3.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# unixReviewTime  1.433808e+09  1.461974e+09  1.483747e+09  1.538352e+09

# %% [markdown]
# # **Dropping Irrelavent columns**

# %%
data.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 1        2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2        4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3        2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 6        4      True  05 31, 2014   A7QS961ROI6E0  7106116521
# 7        3      True  09 22, 2013  A1BB77SEBQT8VX  B00007GDFV
#
#          reviewerName                                         reviewText  \
# 1           Sonja Lau  I agree with the other review, the opening is ...
# 2            Kathleen  Love these... I am going to order another pack...
# 3         Jodi Stoner                                too tiny an opening
# 6    REBECCA S LAYTON  These little plastic backs work great.  No mor...
# 7  Darrow H Ankrum II  mother - in - law wanted it as a present for h...
#
#                                              summary  unixReviewTime
# 1  I agree with the other review, the opening is ...      1411862400
# 2                                My New 'Friends' !!      1408924800
# 3                                          Two Stars      1408838400
# 6                                       Works great!      1401494400
# 7                                bought as a present      1379808000

# %%
data.drop(columns=["unixReviewTime", "asin", "reviewerName", 'reviewerID', ], inplace=True)

# %%
data.head()
# Out:
#    overall  verified   reviewTime  \
# 1        2      True  09 28, 2014
# 2        4     False  08 25, 2014
# 3        2      True  08 24, 2014
# 6        4      True  05 31, 2014
# 7        3      True  09 22, 2013
#
#                                           reviewText  \
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 6  These little plastic backs work great.  No mor...
# 7  mother - in - law wanted it as a present for h...
#
#                                              summary
# 1  I agree with the other review, the opening is ...
# 2                                My New 'Friends' !!
# 3                                          Two Stars
# 6                                       Works great!
# 7                                bought as a present

# %% [markdown]
# # **Saving Data**

# %%
location = f'{path}/FshionProductReviews_V2.csv'
data.to_csv(location, index=False)
