# %% [markdown]
# # **Imports**

# %%
! pip install --upgrade scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (3.1.0)

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBRFClassifier, XGBClassifier
from sklearn.metrics import classification_report

# %%
from pprint import pprint

# %% [markdown]
# # **Load Data**

# %%
dataset = np.load('/content/drive/MyDrive/Colab Notebooks/amazon/dataset.npz')

# %%
dataset.files
# Out:
# ['train_embeddings', 'train_sentiment', 'test_embeddings', 'test_sentiment']

# %%
xtrain, xtest = dataset['train_embeddings'], dataset['test_embeddings']
ytrain, ytest = dataset['train_sentiment'], dataset['test_sentiment']

# %%
xtrain.shape
# Out:
# (18000, 40)

# %% [markdown]
# # **Dimentionality Reduction**

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(
    n_components=10,whiten=True, 
    svd_solver='auto', tol=0.0, 
    iterated_power='auto', n_oversamples=10, 
    power_iteration_normalizer='auto', 
    random_state=33
)

# %%
pca.fit(xtrain, ytrain)
# Out:
# PCA(n_components=10, random_state=33, whiten=True)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.07707273, 0.05935486, 0.05238611, 0.04740816, 0.0362368 ,
#        0.03278863, 0.03086394, 0.02876552, 0.02774145, 0.02707267])

# %%
pca.transform(xtrain)
# Out:
# array([[ 1.70962668,  0.71973385, -1.5831303 , ..., -1.07751818,
#         -0.03520121, -0.44035968],
#        [-0.94327462, -1.2895529 ,  0.2986738 , ..., -0.31328363,
#         -0.27325362, -0.27367544],
#        [ 0.08840278, -0.29230319, -0.17339626, ..., -0.28411999,
#         -0.16446469,  0.0535404 ],
#        ...,
#        [-0.03699793, -0.32522795, -0.23225836, ..., -0.26056812,
#          0.17237214,  0.02192863],
#        [ 1.67339662,  0.47135099, -1.93060999, ..., -1.96724546,
#         -0.3926709 ,  0.22233185],
#        [ 0.13611274, -0.47831107, -0.434717  , ..., -1.04006355,
#          0.70917487,  0.17752259]])

# %%
xtrain_rd, xtest_rd = pca.fit_transform(xtrain), pca.fit_transform(xtest)

# %%
xtrain.shape
# Out:
# (18000, 40)

# %% [markdown]
# # **Support Vector Machine**

# %%
def train_evaluate(model, x, y) -> str:
    model.fit(x, y)
    ypred = model.predict(x)
    report = classification_report(
        ypred, y, output_dict=True
    )
    return model, report

# %%
def test_evaluate(model, x, y) -> str:
    ypred = model.predict(x)
    report = classification_report(
        ypred, y,  output_dict=True
    )
    return report

# %%
svc = SVC(
    C=2.5, kernel='rbf', degree=3, gamma='scale', 
    coef0=0.0, shrinking=True, probability=True, 
    tol=0.001, cache_size=200, class_weight=None, 
    verbose=False, max_iter=-1, decision_function_shape='ovo', 
    break_ties=False, random_state=33
)
svc
# Out:
# SVC(C=2.5, decision_function_shape='ovo', probability=True, random_state=33)

# %%
model_svc, report_svc = train_evaluate(
    svc,
    xtrain_rd, ytrain
)

# %%
pprint(report_svc)
# Out:
# {'0': {'f1-score': 0.9110895240042947,
#        'precision': 0.9917631344612645,
#        'recall': 0.8425531914893617,
#        'support': 10575},
#  '1': {'f1-score': 0.8942278450215925,
#        'precision': 0.8153283052351376,
#        'recall': 0.99003367003367,
#        'support': 7425},
#  'accuracy': 0.9033888888888889,
#  'macro avg': {'f1-score': 0.9026586845129436,
#                'precision': 0.9035457198482011,
#                'recall': 0.9162934307615158,
#                'support': 18000},
#  'weighted avg': {'f1-score': 0.90413408142393,
#                   'precision': 0.9189837674054873,
#                   'recall': 0.9033888888888889,
#                   'support': 18000}}

# %%
test_report = test_evaluate(model_svc, xtest_rd, ytest)

# %%
pprint(test_report)
# Out:
# {'0': {'f1-score': 0.8159600997506234,
#        'precision': 0.8051181102362205,
#        'recall': 0.8270980788675429,
#        'support': 989},
#  '1': {'f1-score': 0.8150375939849623,
#        'precision': 0.8262195121951219,
#        'recall': 0.8041543026706232,
#        'support': 1011},
#  'accuracy': 0.8155,
#  'macro avg': {'f1-score': 0.8154988468677928,
#                'precision': 0.8156688112156711,
#                'recall': 0.815626190769083,
#                'support': 2000},
#  'weighted avg': {'f1-score': 0.8154937730860817,
#                   'precision': 0.8157848689264452,
#                   'recall': 0.8155,
#                   'support': 2000}}

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgrc = LogisticRegression(
    penalty='l2', dual=False, tol=0.0001, 
    C=2.0, fit_intercept=True, intercept_scaling=1, class_weight=None, 
    random_state=33, solver='lbfgs', max_iter=100, multi_class='auto', 
    verbose=0, warm_start=True, n_jobs=None, l1_ratio=None
)

# %%
model_lgrc, report_svc = train_evaluate(
    lgrc,
    xtrain_rd, ytrain
)
pprint(report_svc)
# Out:
# {'0': {'f1-score': 0.9056215604587768,
#        'precision': 0.9799643811219947,
#        'recall': 0.8417630748637537,
#        'support': 10459},
#  '1': {'f1-score': 0.8891707434921784,
#        'precision': 0.8164374445430346,
#        'recall': 0.9761304866728551,
#        'support': 7541},
#  'accuracy': 0.8980555555555556,
#  'macro avg': {'f1-score': 0.8973961519754776,
#                'precision': 0.8982009128325146,
#                'recall': 0.9089467807683044,
#                'support': 18000},
#  'weighted avg': {'f1-score': 0.898729582084048,
#                   'precision': 0.9114556795252202,
#                   'recall': 0.8980555555555556,
#                   'support': 18000}}

# %%
report_lgrc_test = test_evaluate(
    lgrc,
    xtest_rd, ytest
)
pprint(report_lgrc_test)
# Out:
# {'0': {'f1-score': 0.7594501718213058,
#        'precision': 0.6525590551181102,
#        'recall': 0.9082191780821918,
#        'support': 730},
#  '1': {'f1-score': 0.8136645962732918,
#        'precision': 0.931910569105691,
#        'recall': 0.7220472440944882,
#        'support': 1270},
#  'accuracy': 0.79,
#  'macro avg': {'f1-score': 0.7865573840472988,
#                'precision': 0.7922348121119006,
#                'recall': 0.81513321108834,
#                'support': 2000},
#  'weighted avg': {'f1-score': 0.7938763313483169,
#                   'precision': 0.829947266500224,
#                   'recall': 0.79,
#                   'support': 2000}}

# %% [markdown]
# # Naive Bayes

# %%
gnb = GaussianNB()
gnb
# Out:
# GaussianNB()

# %%
fitted_model, naive_report = train_evaluate(
    gnb, xtrain_rd, ytrain
)

# %%
pprint(naive_report)
# Out:
# {'0': {'f1-score': 0.8406452882156208,
#        'precision': 0.951246660730187,
#        'recall': 0.7530842439196335,
#        'support': 11348},
#  '1': {'f1-score': 0.7932090885882053,
#        'precision': 0.6892191659272404,
#        'recall': 0.934155141310884,
#        'support': 6652},
#  'accuracy': 0.82,
#  'macro avg': {'f1-score': 0.816927188401913,
#                'precision': 0.8202329133287137,
#                'recall': 0.8436196926152587,
#                'support': 18000},
#  'weighted avg': {'f1-score': 0.823114977108867,
#                   'precision': 0.8544129443174535,
#                   'recall': 0.82,
#                   'support': 18000}}

# %%
ypred_nb = fitted_model.predict(xtest_rd)
test_report_nb = classification_report(
    ypred_nb, ytest
)
print(test_report_nb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80      1144
#            1       0.72      0.82      0.77       856
#
#     accuracy                           0.78      2000
#    macro avg       0.78      0.79      0.78      2000
# weighted avg       0.79      0.78      0.79      2000

# %% [markdown]
# # Multi-Layer Perceptron

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100, 64, 32, 20, 10), activation='relu', solver='adam', alpha=0.0001,
    batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
    power_t=0.5, max_iter=1000, shuffle=True, random_state=33, tol=0.0001, 
    verbose=True, warm_start=True, momentum=0.9, nesterovs_momentum=True, 
    early_stopping=False, validation_fraction=0.2, beta_1=0.9, beta_2=0.999,
    epsilon=1e-08, n_iter_no_change=20, max_fun=15000
)

# %%
mlp_fitted_model, mlp_report = train_evaluate(
    mlp, xtrain_rd, ytrain
)
# Out:
# Iteration 1, loss = 0.44193625
# Iteration 2, loss = 0.24410332
# Iteration 3, loss = 0.23675202
# Iteration 4, loss = 0.22948226
# Iteration 5, loss = 0.22594188
# Iteration 6, loss = 0.22630213
# Iteration 7, loss = 0.22386193
# Iteration 8, loss = 0.22239158
# Iteration 9, loss = 0.22249199
# Iteration 10, loss = 0.22089512
# Iteration 11, loss = 0.22205935
# Iteration 12, loss = 0.22074852
# Iteration 13, loss = 0.22065486
# Iteration 14, loss = 0.21890567
# Iteration 15, loss = 0.21819066
# Iteration 16, loss = 0.21937206
# Iteration 17, loss = 0.21888885
# Iteration 18, loss = 0.21729610
# Iteration 19, loss = 0.21743893
# Iteration 20, loss = 0.21673289
# Iteration 21, loss = 0.21585416
# Iteration 22, loss = 0.21587889
# Iteration 23, loss = 0.21557092
# Iteration 24, loss = 0.21591150
# Iteration 25, loss = 0.21535462
# Iteration 26, loss = 0.21579181
# Iteration 27, loss = 0.21539807
# Iteration 28, loss = 0.21540911
# Iteration 29, loss = 0.21417454
# Iteration 30, loss = 0.21499189
# Iteration 31, loss = 0.21415246
# Iteration 32, loss = 0.21514332
# Iteration 33, loss = 0.21436680
# Iteration 34, loss = 0.21445050
# Iteration 35, loss = 0.21390433
# Iteration 36, loss = 0.21537494
# Iteration 37, loss = 0.21318550
# Iteration 38, loss = 0.21425158
# Iteration 39, loss = 0.21345712
# Iteration 40, loss = 0.21320011
# Iteration 41, loss = 0.21405703
# Iteration 42, loss = 0.21286006
# Iteration 43, loss = 0.21216100
# Iteration 44, loss = 0.21315667
# Iteration 45, loss = 0.21241553
# Iteration 46, loss = 0.21212340
# Iteration 47, loss = 0.21141002
# Iteration 48, loss = 0.21125410
# Iteration 49, loss = 0.21190184
# Iteration 50, loss = 0.21122834
# Iteration 51, loss = 0.21080001
# Iteration 52, loss = 0.21097306
# Iteration 53, loss = 0.21058218
# Iteration 54, loss = 0.21076289
# Iteration 55, loss = 0.21021680
# Iteration 56, loss = 0.21051926
# Iteration 57, loss = 0.20910638
# Iteration 58, loss = 0.20992049
# Iteration 59, loss = 0.20879581
# Iteration 60, loss = 0.20827350
# Iteration 61, loss = 0.20881815
# Iteration 62, loss = 0.21003488
# Iteration 63, loss = 0.20818126
# Iteration 64, loss = 0.20825686
# Iteration 65, loss = 0.20866717
# Iteration 66, loss = 0.20813079
# Iteration 67, loss = 0.20848436
# Iteration 68, loss = 0.20812428
# Iteration 69, loss = 0.20880457
# Iteration 70, loss = 0.20730452
# Iteration 71, loss = 0.20763395
# Iteration 72, loss = 0.20787354
# Iteration 73, loss = 0.20642315
# Iteration 74, loss = 0.20715825
# Iteration 75, loss = 0.20589542
# Iteration 76, loss = 0.20640682
# Iteration 77, loss = 0.20622987
# Iteration 78, loss = 0.20601256
# Iteration 79, loss = 0.20563300
# Iteration 80, loss = 0.20524057
# Iteration 81, loss = 0.20523058
# Iteration 82, loss = 0.20594098
# Iteration 83, loss = 0.20567904
# Iteration 84, loss = 0.20507623
# Iteration 85, loss = 0.20490701
# Iteration 86, loss = 0.20474029
# Iteration 87, loss = 0.20510302
# Iteration 88, loss = 0.20492583
# Iteration 89, loss = 0.20371473
# Iteration 90, loss = 0.20443724
# Iteration 91, loss = 0.20401489
# Iteration 92, loss = 0.20430816
# Iteration 93, loss = 0.20456847
# Iteration 94, loss = 0.20421739
# Iteration 95, loss = 0.20448792
# Iteration 96, loss = 0.20308609
# Iteration 97, loss = 0.20431423
# Iteration 98, loss = 0.20359062
# Iteration 99, loss = 0.20337583
# Iteration 100, loss = 0.20415777
# Iteration 101, loss = 0.20303495
# Iteration 102, loss = 0.20295905
# Iteration 103, loss = 0.20368120
# Iteration 104, loss = 0.20197092
# Iteration 105, loss = 0.20229060
# Iteration 106, loss = 0.20175079
# Iteration 107, loss = 0.20304133
# Iteration 108, loss = 0.20361441
# Iteration 109, loss = 0.20193391
# Iteration 110, loss = 0.20206976
# Iteration 111, loss = 0.20292470
# Iteration 112, loss = 0.20163351
# Iteration 113, loss = 0.20143088
# Iteration 114, loss = 0.20313349
# Iteration 115, loss = 0.20073573
# Iteration 116, loss = 0.20135293
# Iteration 117, loss = 0.20033619
# Iteration 118, loss = 0.20047117
# Iteration 119, loss = 0.20132715
# Iteration 120, loss = 0.20073175
# Iteration 121, loss = 0.20069729
# Iteration 122, loss = 0.20140445
# Iteration 123, loss = 0.20021159
# Iteration 124, loss = 0.20051778
# Iteration 125, loss = 0.20013710
# Iteration 126, loss = 0.19993802
# Iteration 127, loss = 0.20024052
# Iteration 128, loss = 0.20120476
# Iteration 129, loss = 0.20073765
# Iteration 130, loss = 0.20068599
# Iteration 131, loss = 0.20302108
# Iteration 132, loss = 0.20086374
# Iteration 133, loss = 0.20127779
# Iteration 134, loss = 0.20003915
# Iteration 135, loss = 0.19895143
# Iteration 136, loss = 0.19877970
# Iteration 137, loss = 0.19917906
# Iteration 138, loss = 0.19866668
# Iteration 139, loss = 0.19912317
# Iteration 140, loss = 0.19916780
# Iteration 141, loss = 0.19924555
# Iteration 142, loss = 0.19803581
# Iteration 143, loss = 0.19852860
# Iteration 144, loss = 0.19903017
# Iteration 145, loss = 0.19843545
# Iteration 146, loss = 0.19777198
# Iteration 147, loss = 0.19772237
# Iteration 148, loss = 0.19968688
# Iteration 149, loss = 0.20250568
# Iteration 150, loss = 0.20032503
# Iteration 151, loss = 0.19832106
# Iteration 152, loss = 0.19829090
# Iteration 153, loss = 0.19916134
# Iteration 154, loss = 0.19853736
# Iteration 155, loss = 0.19745645
# Iteration 156, loss = 0.19768912
# Iteration 157, loss = 0.19693161
# Iteration 158, loss = 0.19655201
# Iteration 159, loss = 0.19838237
# Iteration 160, loss = 0.19887005
# Iteration 161, loss = 0.19812312
# Iteration 162, loss = 0.19676771
# Iteration 163, loss = 0.19600737
# Iteration 164, loss = 0.20007025
# Iteration 165, loss = 0.20025903
# Iteration 166, loss = 0.19736360
# Iteration 167, loss = 0.19655978
# Iteration 168, loss = 0.19690925
# Iteration 169, loss = 0.19804768
# Iteration 170, loss = 0.19664829
# Iteration 171, loss = 0.19582587
# Iteration 172, loss = 0.19620451
# Iteration 173, loss = 0.19666630
# Iteration 174, loss = 0.19757729
# Iteration 175, loss = 0.19696892
# Iteration 176, loss = 0.19708524
# Iteration 177, loss = 0.19647614
# Iteration 178, loss = 0.19706405
# Iteration 179, loss = 0.19638849
# Iteration 180, loss = 0.19617901
# Iteration 181, loss = 0.19573246
# Iteration 182, loss = 0.19531851
# Iteration 183, loss = 0.19566579
# Iteration 184, loss = 0.19556887
# Iteration 185, loss = 0.19895163
# Iteration 186, loss = 0.19822935
# Iteration 187, loss = 0.19793207
# Iteration 188, loss = 0.19696933
# Iteration 189, loss = 0.19603202
# Iteration 190, loss = 0.19598026
# Iteration 191, loss = 0.19451155
# Iteration 192, loss = 0.19515704
# Iteration 193, loss = 0.19468494
# Iteration 194, loss = 0.19446772
# Iteration 195, loss = 0.19416746
# Iteration 196, loss = 0.19495425
# Iteration 197, loss = 0.19810523
# Iteration 198, loss = 0.19804087
# Iteration 199, loss = 0.19537349
# Iteration 200, loss = 0.19530141
# Iteration 201, loss = 0.19451806
# Iteration 202, loss = 0.19453090
# Iteration 203, loss = 0.19519635
# Iteration 204, loss = 0.19399004
# Iteration 205, loss = 0.19620348
# Iteration 206, loss = 0.19569905
# Iteration 207, loss = 0.19602401
# Iteration 208, loss = 0.19446507
# Iteration 209, loss = 0.19512672
# Iteration 210, loss = 0.19395997
# Iteration 211, loss = 0.19351970
# Iteration 212, loss = 0.19420797
# Iteration 213, loss = 0.19379823
# Iteration 214, loss = 0.19363213
# Iteration 215, loss = 0.19371619
# Iteration 216, loss = 0.19683492
# Iteration 217, loss = 0.19342829
# Iteration 218, loss = 0.19452112
# Iteration 219, loss = 0.19360312
# Iteration 220, loss = 0.19333286
# Iteration 221, loss = 0.19272240
# Iteration 222, loss = 0.19561184
# Iteration 223, loss = 0.19374891
# Iteration 224, loss = 0.19360107
# Iteration 225, loss = 0.19351758
# Iteration 226, loss = 0.19424370
# Iteration 227, loss = 0.19371291
# Iteration 228, loss = 0.19323307
# Iteration 229, loss = 0.19250893
# Iteration 230, loss = 0.19390349
# Iteration 231, loss = 0.19245790
# Iteration 232, loss = 0.19528612
# Iteration 233, loss = 0.19289386
# Iteration 234, loss = 0.19259695
# Iteration 235, loss = 0.19307053
# Iteration 236, loss = 0.19330314
# Iteration 237, loss = 0.19298359
# Iteration 238, loss = 0.19251438
# Iteration 239, loss = 0.19527530
# Iteration 240, loss = 0.19413389
# Iteration 241, loss = 0.19244722
# Iteration 242, loss = 0.19220685
# Iteration 243, loss = 0.19230481
# Iteration 244, loss = 0.19209633
# Iteration 245, loss = 0.19207177
# Iteration 246, loss = 0.19259982
# Iteration 247, loss = 0.19164176
# Iteration 248, loss = 0.19147896
# Iteration 249, loss = 0.19199251
# Iteration 250, loss = 0.19219973
# Iteration 251, loss = 0.19319066
# Iteration 252, loss = 0.19467072
# Iteration 253, loss = 0.19246213
# Iteration 254, loss = 0.19224345
# Iteration 255, loss = 0.19332776
# Iteration 256, loss = 0.19320641
# Iteration 257, loss = 0.19301246
# Iteration 258, loss = 0.19478165
# Iteration 259, loss = 0.19173812
# Iteration 260, loss = 0.19190859
# Iteration 261, loss = 0.19058436
# Iteration 262, loss = 0.19145659
# Iteration 263, loss = 0.19240511
# Iteration 264, loss = 0.19126510
# Iteration 265, loss = 0.19194961
# Iteration 266, loss = 0.19228104
# Iteration 267, loss = 0.19165298
# Iteration 268, loss = 0.19173153
# Iteration 269, loss = 0.19268430
# Iteration 270, loss = 0.19092026
# Iteration 271, loss = 0.19034032
# Iteration 272, loss = 0.18966396
# Iteration 273, loss = 0.19039401
# Iteration 274, loss = 0.19162256
# Iteration 275, loss = 0.19010402
# Iteration 276, loss = 0.19169651
# Iteration 277, loss = 0.19115448
# Iteration 278, loss = 0.19033264
# Iteration 279, loss = 0.19109240
# Iteration 280, loss = 0.19005332
# Iteration 281, loss = 0.19080009
# Iteration 282, loss = 0.19121273
# Iteration 283, loss = 0.19194518
# Iteration 284, loss = 0.19252306
# Iteration 285, loss = 0.19426828
# Iteration 286, loss = 0.19267145
# Iteration 287, loss = 0.19085371
# Iteration 288, loss = 0.19183300
# Iteration 289, loss = 0.19071247
# Iteration 290, loss = 0.18983855
# Iteration 291, loss = 0.19113020
# Iteration 292, loss = 0.19121313
# Iteration 293, loss = 0.19425991
# Training loss did not improve more than tol=0.000100 for 20 consecutive epochs. Stopping.

# %%
pprint(mlp_report)
# Out:
# {'0': {'f1-score': 0.9210160234942553,
#        'precision': 0.994879786286732,
#        'recall': 0.8573621103117506,
#        'support': 10425},
#  '1': {'f1-score': 0.9076005062985957,
#        'precision': 0.8350709849157054,
#        'recall': 0.9939273927392739,
#        'support': 7575},
#  'accuracy': 0.9148333333333334,
#  'macro avg': {'f1-score': 0.9143082648964255,
#                'precision': 0.9149753856012187,
#                'recall': 0.9256447515255122,
#                'support': 18000},
#  'weighted avg': {'f1-score': 0.9153703266744152,
#                   'precision': 0.9276269157097583,
#                   'recall': 0.9148333333333334,
#                   'support': 18000}}

# %%
mlp_test_report = test_evaluate(
    mlp_fitted_model, xtest_rd, ytest
)

# %%
pprint(mlp_test_report)
# Out:
# {'0': {'f1-score': 0.610146862483311,
#        'precision': 0.4498031496062992,
#        'recall': 0.9481327800829875,
#        'support': 482},
#  '1': {'f1-score': 0.7665867306155076,
#        'precision': 0.9745934959349594,
#        'recall': 0.6317523056653491,
#        'support': 1518},
#  'accuracy': 0.708,
#  'macro avg': {'f1-score': 0.6883667965494094,
#                'precision': 0.7121983227706292,
#                'recall': 0.7899425428741683,
#                'support': 2000},
#  'weighted avg': {'f1-score': 0.7288847223956483,
#                   'precision': 0.8481190224697522,
#                   'recall': 0.708,
#                   'support': 2000}}

# %% [markdown]
# # XG BOOSt

# %%
! pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (1.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.10.1)

# %%
from xgboost import XGBClassifier

# %%
bst = XGBClassifier(base_score=None, booster=None, callbacks=None,
              colsample_bylevel=None, colsample_bynode=None,
              colsample_bytree=None, early_stopping_rounds=None,
              enable_categorical=False, eval_metric=None, feature_types=None,
              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
              interaction_constraints=None, learning_rate=1, max_bin=None,
              max_cat_threshold=None, max_cat_to_onehot=None,
              max_delta_step=None, max_depth=4, max_leaves=None,
              min_child_weight=None, monotone_constraints=None,
              n_estimators=50, n_jobs=None, num_parallel_tree=None,
              predictor=None, random_state=33)
bst
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=33, ...)

# %%
bst_fitted_model, bst_report = train_evaluate(
    bst, xtrain_rd, ytrain
)

# %%
pprint(bst_report)
# Out:
# {'0': {'f1-score': 0.922089351348553,
#        'precision': 0.9913178984861977,
#        'recall': 0.8618987709280944,
#        'support': 10333},
#  '1': {'f1-score': 0.9097884073607864,
#        'precision': 0.8417258207630879,
#        'recall': 0.9898265292813356,
#        'support': 7667},
#  'accuracy': 0.9163888888888889,
#  'macro avg': {'f1-score': 0.9159388793546697,
#                'precision': 0.9165218596246427,
#                'recall': 0.925862650104715,
#                'support': 18000},
#  'weighted avg': {'f1-score': 0.9168498325955414,
#                   'precision': 0.9275999840471375,
#                   'recall': 0.9163888888888889,
#                   'support': 18000}}

# %%
bst_test_report = test_evaluate(
    bst_fitted_model, xtest_rd, ytest
)

# %%
pprint(bst_test_report)
# Out:
# {'0': {'f1-score': 0.6309601567602874,
#        'precision': 0.47539370078740156,
#        'recall': 0.9378640776699029,
#        'support': 515},
#  '1': {'f1-score': 0.7711624139327663,
#        'precision': 0.967479674796748,
#        'recall': 0.641077441077441,
#        'support': 1485},
#  'accuracy': 0.7175,
#  'macro avg': {'f1-score': 0.7010612853465268,
#                'precision': 0.7214366877920748,
#                'recall': 0.789470759373672,
#                'support': 2000},
#  'weighted avg': {'f1-score': 0.735060332710853,
#                   'precision': 0.8407675364893413,
#                   'recall': 0.7175,
#                   'support': 2000}}

# %%
grid = RandomizedSearchCV(
    bst,
    param_distributions = {
        'n_estimators':[50, 75, 100, 150, 200],
        'max_depth':[3, 4, 5], 
        'learning_rate':[1, 2,3], 
    }, 
    cv=20, 
    scoring=['accuracy', 'f1', 'precision', 'recall'], 
    random_state=33, 
    n_iter=2, 
    refit='accuracy', 
    verbose=1
)
grid.fit(xtrain_rd, ytrain)
# Out:
# Fitting 20 folds for each of 2 candidates, totalling 40 fits
# RandomizedSearchCV(cv=20,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rat...
#                                            max_leaves=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=50, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=33, ...),
#                    n_iter=2,
#                    param_distributions={'learning_rate': [1, 2, 3],
#                                         'max_depth': [3, 4, 5],
#                                         'n_estimators': [50, 75, 100, 150,
#                                                          200]},
#                    random_state=33, refit='accuracy',
#                    scoring=['accuracy', 'f1', 'precision', 'recall'],
#                    verbose=1)

# %%
grid.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=33, ...)

# %%
grid.best_score_
# Out:
# 0.9018888888888886

# %% [markdown]
# # Store Metrics

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score
import warnings
warnings.filterwarnings(action='ignore')

# %%
# metrics = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amazon/Metrics.csv')
# metrics

# %%
def get_metrics(model, x, y, model_name, type_) :
  global metrics
  ypred = model.predict(x)
  scores = pd.Series(
      [
          model_name, 
          accuracy_score(y_true=y, y_pred=ypred),
          precision_score(y_true=y, y_pred=ypred),
          recall_score(y_true=y, y_pred=ypred),
          f1_score(y_true=y, y_pred=ypred),
          roc_auc_score(y_true=y, y_score=ypred),
          type_
      ], index=metrics.columns
  )
  metrics = metrics.append(
      scores, ignore_index=True
  )

# %%
get_metrics(model_svc, xtrain_rd, ytrain, model_name='SVC', type_='train')
get_metrics(model_svc, xtest_rd, ytest, model_name='SVC', type_='test')

# %%
get_metrics(bst, xtrain_rd, ytrain, model_name='XGBClassifier', type_='train')
get_metrics(bst, xtest_rd, ytest, model_name='XGBClassifier', type_='test')

# %%
get_metrics(fitted_model, xtrain_rd, ytrain, model_name='NaiveBayes', type_='train')
get_metrics(fitted_model, xtest_rd, ytest, model_name='NaiveBayes', type_='test')

# %%
get_metrics(mlp_fitted_model, xtrain_rd, ytrain, model_name='MLP', type_='train')
get_metrics(mlp_fitted_model, xtest_rd, ytest, model_name='MLP', type_='test')

# %%
get_metrics(grid.best_estimator_, xtrain_rd, ytrain, model_name='XGBClassifier', type_='train')
get_metrics(grid.best_estimator_, xtest_rd, ytest, model_name='XGBClassifier', type_='test')

# %%
get_metrics(lgrc, xtrain_rd, ytrain, model_name='LogisticRegression', type_='train')
get_metrics(lgrc, xtest_rd, ytest, model_name='LogisticRegression', type_='test')

# %%
metrics
# Out:
#                  model  accuracy  precision    recall  f1_score  \
# 0                  SVC  0.903389   0.990034  0.815328  0.894228
# 1                  SVC  0.815500   0.804154  0.826220  0.815038
# 2        XGBClassifier  0.916389   0.989827  0.841726  0.909788
# 3        XGBClassifier  0.717500   0.641077  0.967480  0.771162
# 4           NaiveBayes  0.820000   0.934155  0.689219  0.793209
# ..                 ...       ...        ...       ...       ...
# 67                 MLP  0.708000   0.631752  0.974593  0.766587
# 68       XGBClassifier  0.916389   0.989827  0.841726  0.909788
# 69       XGBClassifier  0.717500   0.641077  0.967480  0.771162
# 70  LogisticRegression  0.898056   0.976130  0.816437  0.889171
# 71  LogisticRegression  0.790000   0.722047  0.931911  0.813665
#
#     roc_auc_score   type
# 0        0.903546  train
# 1        0.815669   test
# 2        0.916522  train
# 3        0.721437   test
# 4        0.820233  train
# ..            ...    ...
# 67       0.712198   test
# 68       0.916522  train
# 69       0.721437   test
# 70       0.898201  train
# 71       0.792235   test
#
# [72 rows x 7 columns]

# %%
metrics.to_csv(
    '/content/drive/MyDrive/Colab Notebooks/amazon/Metrics.csv', index=False
)
